# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Maior2022=pd.read_csv("Desemp_MAIOR_2022.csv",sep=";")
MENOR2022=pd.read_csv("Desemp_MENOR_2022.csv",sep=";")

# %%
print(f"Maior - 2022 - Maculino:{len(Maior2022.query('TP_SEXO==13'))}")
print(f"Maior - 2022 - Feminino:{len(Maior2022.query('TP_SEXO==6'))}")
print(f"Menor - 2022 - Maculino:{len(MENOR2022.query('TP_SEXO==13'))}")
print(f"Menor - 2022 - Feminino:{len(MENOR2022.query('TP_SEXO==6'))}")
# Out:
# Maior - 2022 - Maculino:364004
# Maior - 2022 - Feminino:494503
# Menor - 2022 - Maculino:316669
# Menor - 2022 - Feminino:541838
